# %%
from pathlib import Path

import matplotlib.pyplot as plt

from src.models.recipes_models.image_recipe_model import ImageRecipe
from src.pipeline.orchestrator import create_image

# %%
# Путь к папке с снимками
root_path = "../data/ASI0/2023/10/11/6300"
root_path = Path(root_path)

# %%
# Создание рецепта (список настроек)
img_recipe = ImageRecipe(
    root_path=root_path
)
img_recipe.frame_number = 200
img_recipe.save_folder = ""

# %%
img = create_image(img_recipe)

# %%
plt.imshow(img.view_data, cmap="gray")
plt.axis('off')
plt.show()
